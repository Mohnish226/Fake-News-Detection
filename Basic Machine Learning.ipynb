# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import feature_extraction, model_selection, preprocessing
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
import glob 
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re
import random
from string import punctuation
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
lemmatizer = WordNetLemmatizer()
stop = set(stopwords.words('english'))
stop.update(list(punctuation))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Some parts of progressbar from tqdm will not be seen on github, it will look like -> HBox(children=......)

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %% [markdown]
# Get Datasets

# %%
def get_datasets(shuffle=False):
    df = pd.DataFrame()
    for file in tqdm(glob.glob('Datasets/*/*_*.csv')):
        df = df.append(pd.read_csv(file), ignore_index=True)
    if shuffle:
    	#df = df.sample(frac=1).reset_index(drop=True)
    	df = df.reindex(np.random.permutation(df.index)).reset_index(drop=True)
    return df

# %% [markdown]
# As seen in Analysis.ipynb, there are more 0's than 1's So normalize keeping some difference

# %%
def normalize(df,difference=300):
    df_list = [df[df['fake']==0],df[df['fake']==1]] # [fact,fake]
    lst = [len(df_list[0]),len(df_list[1])]
    if not bool(lst.index(min(lst))):
        """ if fake is larger than swap """
        df_list[0], df_list[1] = df_list[1], df_list[0]
    size = len(df_list[0]) - len(df_list[1]) + difference
    to_delete = random.sample(range(0, len(df_list[0])), size)
    df_list[0] = df_list[0].drop(df_list[0].index[to_delete])
    #print("FACT: {} FAKE:{} Difference:{}".format(len(df_list[0]),len(df_list[1]),len(df_list[1])-len(df_list[0])))
    return df_list[0].append(df_list[1], ignore_index=True).sample(frac=1)

# %% [markdown]
# Cleaning Text, removing html tags, url's, digits stopwords, them lemmatizing them

# %%
def text_clean(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'http\S+', '', text)
    text = " ".join(x for x in word_tokenize(str(text)) if x.strip().lower() not in stop)
    text = re.sub(r'\d+', '', text)
    text = " ".join(lemmatizer.lemmatize(x.lower()) for x in text.split())
    return(text)

# %%
def pre_process():
    df = normalize(get_datasets(shuffle=True))
    print("Normalized")
    df = df.replace(np.nan, '', regex=True)
    df['news'] = df['title'].str.cat(df['text'],sep=" ")
    print("Cleaning")
    df['news'] = df['news'].progress_apply(text_clean)
    df = df.drop(['title','text'], axis=1)
    return df

# %%
df = pre_process()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=83.0), HTML(value='')))
# Normalized
# Cleaning
# HBox(children=(FloatProgress(value=0.0, max=72660.0), HTML(value='')))

# %%
x_train,x_test,y_train,y_test = train_test_split(df['news'].values, df['fake'].values, test_size=0.2, random_state=2020)

# %%
def pipeline_model(pipe, x_train, y_train, x_test, y_test):
    model = pipe.fit(x_train, y_train)
    prediction = model.predict(x_test)
    print("accuracy: {}".format(round(accuracy_score(y_test, prediction)*100,2)))

# %% [markdown]
# The text is first converted to a count vectorizer then TFIDF (Term Frequency Inverse Document Frequency)

# %% [markdown]
# <h3>Logistic Regression</h3>

# %%
pipeline_model(Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())]),
                   x_train, y_train, x_test, y_test)
# Out:
# accuracy: 93.48

# %% [markdown]
# <h3>Linear Support Vector Classification</h3>

# %%
pipeline_model(Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LinearSVC())]),
                  x_train, y_train, x_test, y_test)
# Out:
# accuracy: 95.08

# %% [markdown]
# Using Grid Search CV to get best parameters fot Linear SVC

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'multi_class': ['ovr','crammer_singer'], 
              'tol': [1e-3, 1e-4],
              #'dual': [True,False], 
              'loss': ['hinge','squared_hinge'],
              'penalty':['l1','l2'], 
              'C': [1, 10]} #, 00, 1000]}

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', GridSearchCV(LinearSVC(),parameters, refit = True, verbose=2))])

model = pipe.fit(x_train,y_train)
model.named_steps['model'].best_params_
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 .........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.1s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   3.6s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   7.3s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   3.3s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   8.0s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 .........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   3.8s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   3.7s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 ........
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   9.4s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   9.2s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   7.7s
# [CV] C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 ........
# [CV]  C=1, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   8.6s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  18.7s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  12.2s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  10.7s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  13.2s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  16.6s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  20.3s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  35.7s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  26.1s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 1.9min
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  53.7s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  15.5s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  18.5s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  27.6s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  32.0s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  30.9s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  17.6s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.1min
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  34.5s
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.8min
# [CV] C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  33.8s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001 .
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True
#
#   FitFailedWarning)
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   1.1s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   1.2s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   1.2s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   1.2s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001 .
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   1.1s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   1.4s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   1.4s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   1.4s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   1.4s
# [CV] C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   1.4s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  15.4s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  16.8s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  21.4s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  12.6s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  27.4s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  20.2s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 1.4min
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  23.8s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 2.1min
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total=  55.6s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  23.1s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  14.7s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  15.8s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  22.3s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  22.6s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  17.0s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  59.8s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  25.5s
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.7min
# [CV] C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=1, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total=  19.7s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=  16.1s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=  12.9s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=  15.4s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=  15.6s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001 ........
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.001, total=  15.7s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=  15.6s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=  14.6s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=  14.6s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=  14.5s
# [CV] C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001 .......
# [CV]  C=10, loss=hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=  14.6s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  33.7s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  21.0s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total= 1.2min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  54.1s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  28.5s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 3.3min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 2.5min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 2.1min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 4.9min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 1.4min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  53.6s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  24.3s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total= 1.4min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total= 1.3min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  51.1s
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 4.0min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 2.5min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 2.2min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 4.5min
# [CV] C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.2min
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l1, tol=0.0001, total=   0.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   6.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   5.9s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   5.7s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   6.4s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.001, total=   6.4s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   7.8s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   8.1s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   7.2s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   8.0s
# [CV] C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=ovr, penalty=l2, tol=0.0001, total=   7.9s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total= 1.7min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  25.6s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total= 1.4min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total= 1.4min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.001, total=  43.8s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 3.3min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 2.4min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 3.2min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 2.9min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l1, tol=0.0001, total= 1.5min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  41.6s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total= 1.1min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total= 1.2min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  45.0s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.001, total=  29.0s
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.6min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 2.6min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 2.0min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 2.9min
# [CV] C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001
# [CV]  C=10, loss=squared_hinge, multi_class=crammer_singer, penalty=l2, tol=0.0001, total= 1.0min
# [Parallel(n_jobs=1)]: Done 160 out of 160 | elapsed: 98.8min finished
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-56735b71caee> in <module>()
#      13
#      14 model = pipe.fit(x_train,y_train)
# ---> 15 model.best_params_
#      16
#      17 '''
#
# AttributeError: 'Pipeline' object has no attribute 'best_params_'

# %%
model.named_steps['model'].best_params_
# Out:
# {'C': 1,
#  'loss': 'squared_hinge',
#  'multi_class': 'ovr',
#  'penalty': 'l2',
#  'tol': 0.001}

# %% [markdown]
# Manually finding Best parameters for XG Boost (Ideally should have used Gridsearch CV but it took lot of time)

# %%
from xgboost import XGBClassifier

for d in [1,5,10,20,50]:
    for n in [1,5,10,20,50]:
        for l in [0.001,0.01,0.05,0.1,0.5,1,2]:
            print("d:{},n:{},l:{}".format(d,n,l))
            pipeline_model(Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('model', XGBClassifier(loss = 'deviance',
                                              learning_rate = l,
                                                   n_estimators = n,
                                                   max_depth = d,
                                                   random_state=2020))]),
                        x_train, y_train, x_test, y_test)
# Out:
# d:1,n:1,l:0.001
# accuracy: 64.22
# d:1,n:1,l:0.01
# accuracy: 64.22
# d:1,n:1,l:0.05
# accuracy: 64.22
# d:1,n:1,l:0.1
# accuracy: 64.22
# d:1,n:1,l:0.5
# accuracy: 64.22
# d:1,n:1,l:1
# accuracy: 64.22
# d:1,n:1,l:2
# accuracy: 64.22
# d:1,n:5,l:0.001
# accuracy: 64.22
# d:1,n:5,l:0.01
# accuracy: 64.4
# d:1,n:5,l:0.05
# accuracy: 70.92
# d:1,n:5,l:0.1
# accuracy: 71.04
# d:1,n:5,l:0.5
# accuracy: 75.87
# d:1,n:5,l:1
# accuracy: 77.45
# d:1,n:5,l:2
# accuracy: 61.65
# d:1,n:10,l:0.001
# accuracy: 64.4
# d:1,n:10,l:0.01
# accuracy: 64.4
# d:1,n:10,l:0.05
# accuracy: 71.04
# d:1,n:10,l:0.1
# accuracy: 76.16
# d:1,n:10,l:0.5
# accuracy: 79.0
# d:1,n:10,l:1
# accuracy: 80.37
# d:1,n:10,l:2
# accuracy: 50.06
# d:1,n:20,l:0.001
# accuracy: 64.4
# d:1,n:20,l:0.01
# accuracy: 70.92
# d:1,n:20,l:0.05
# accuracy: 76.2
# d:1,n:20,l:0.1
# accuracy: 76.63
# d:1,n:20,l:0.5
# accuracy: 84.37
# d:1,n:20,l:1
# accuracy: 85.47
# d:1,n:20,l:2
# accuracy: 50.09
# d:1,n:50,l:0.001
# accuracy: 64.4
# d:1,n:50,l:0.01
# accuracy: 71.04
# d:1,n:50,l:0.05
# accuracy: 76.79
# d:1,n:50,l:0.1
# accuracy: 79.59
# d:1,n:50,l:0.5
# accuracy: 87.56
# d:1,n:50,l:1
# accuracy: 88.7
# d:1,n:50,l:2
# accuracy: 50.09
# d:5,n:1,l:0.001
# accuracy: 77.02
# d:5,n:1,l:0.01
# accuracy: 77.02
# d:5,n:1,l:0.05
# accuracy: 77.02
# d:5,n:1,l:0.1
# accuracy: 77.02
# d:5,n:1,l:0.5
# accuracy: 77.02
# d:5,n:1,l:1
# accuracy: 77.02
# d:5,n:1,l:2
# accuracy: 77.02
# d:5,n:5,l:0.001
# accuracy: 77.02
# d:5,n:5,l:0.01
# accuracy: 76.96
# d:5,n:5,l:0.05
# accuracy: 80.46
# d:5,n:5,l:0.1
# accuracy: 82.15
# d:5,n:5,l:0.5
# accuracy: 86.01
# d:5,n:5,l:1
# accuracy: 87.28
# d:5,n:5,l:2
# accuracy: 79.54
# d:5,n:10,l:0.001
# accuracy: 77.02
# d:5,n:10,l:0.01
# accuracy: 77.04
# d:5,n:10,l:0.05
# accuracy: 82.38
# d:5,n:10,l:0.1
# accuracy: 83.68
# d:5,n:10,l:0.5
# accuracy: 88.98
# d:5,n:10,l:1
# accuracy: 89.63
# d:5,n:10,l:2
# accuracy: 65.15
# d:5,n:20,l:0.001
# accuracy: 77.05
# d:5,n:20,l:0.01
# accuracy: 77.81
# d:5,n:20,l:0.05
# accuracy: 84.19
# d:5,n:20,l:0.1
# accuracy: 86.44
# d:5,n:20,l:0.5
# accuracy: 91.01
# d:5,n:20,l:1
# accuracy: 91.88
# d:5,n:20,l:2
# accuracy: 59.96
# d:5,n:50,l:0.001
# accuracy: 76.98
# d:5,n:50,l:0.01
# accuracy: 82.51
# d:5,n:50,l:0.05
# accuracy: 87.34
# d:5,n:50,l:0.1
# accuracy: 89.87
# d:5,n:50,l:0.5
# accuracy: 93.8
# d:5,n:50,l:1
# accuracy: 93.86
# d:5,n:50,l:2
# accuracy: 50.09
# d:10,n:1,l:0.001
# accuracy: 84.78
# d:10,n:1,l:0.01
# accuracy: 84.78
# d:10,n:1,l:0.05
# accuracy: 84.78
# d:10,n:1,l:0.1
# accuracy: 84.78
# d:10,n:1,l:0.5
# accuracy: 84.78
# d:10,n:1,l:1
# accuracy: 84.78
# d:10,n:1,l:2
# accuracy: 84.78
# d:10,n:5,l:0.001
# accuracy: 84.79
# d:10,n:5,l:0.01
# accuracy: 85.35
# d:10,n:5,l:0.05
# accuracy: 86.46
# d:10,n:5,l:0.1
# accuracy: 86.87
# d:10,n:5,l:0.5
# accuracy: 89.36
# d:10,n:5,l:1
# accuracy: 89.65
# d:10,n:5,l:2
# accuracy: 85.1
# d:10,n:10,l:0.001
# accuracy: 84.82
# d:10,n:10,l:0.01
# accuracy: 85.93
# d:10,n:10,l:0.05
# accuracy: 87.03
# d:10,n:10,l:0.1
# accuracy: 88.1
# d:10,n:10,l:0.5
# accuracy: 91.35
# d:10,n:10,l:1
# accuracy: 91.55
# d:10,n:10,l:2
# accuracy: 86.26
# d:10,n:20,l:0.001
# accuracy: 84.91
# d:10,n:20,l:0.01
# accuracy: 86.48
# d:10,n:20,l:0.05
# accuracy: 88.14
# d:10,n:20,l:0.1
# accuracy: 89.73
# d:10,n:20,l:0.5
# accuracy: 93.14
# d:10,n:20,l:1
# accuracy: 92.82
# d:10,n:20,l:2
# accuracy: 84.81
# d:10,n:50,l:0.001
# accuracy: 85.17
# d:10,n:50,l:0.01
# accuracy: 87.24
# d:10,n:50,l:0.05
# accuracy: 90.51
# d:10,n:50,l:0.1
# accuracy: 92.37
# d:10,n:50,l:0.5
# accuracy: 94.7
# d:10,n:50,l:1
# accuracy: 94.08
# d:10,n:50,l:2
# accuracy: 82.56
# d:20,n:1,l:0.001
# accuracy: 86.94
# d:20,n:1,l:0.01
# accuracy: 86.94
# d:20,n:1,l:0.05
# accuracy: 86.94
# d:20,n:1,l:0.1
# accuracy: 86.94
# d:20,n:1,l:0.5
# accuracy: 86.94
# d:20,n:1,l:1
# accuracy: 86.94
# d:20,n:1,l:2
# accuracy: 86.94
# d:20,n:5,l:0.001
# accuracy: 87.3
# d:20,n:5,l:0.01
# accuracy: 87.73
# d:20,n:5,l:0.05
# accuracy: 88.54
# d:20,n:5,l:0.1
# accuracy: 89.1
# d:20,n:5,l:0.5
# accuracy: 90.63
# d:20,n:5,l:1
# accuracy: 91.07
# d:20,n:5,l:2
# accuracy: 87.67
# d:20,n:10,l:0.001
# accuracy: 87.3
# d:20,n:10,l:0.01
# accuracy: 88.18
# d:20,n:10,l:0.05
# accuracy: 89.22
# d:20,n:10,l:0.1
# accuracy: 90.12
# d:20,n:10,l:0.5
# accuracy: 92.53
# d:20,n:10,l:1
# accuracy: 92.68
# d:20,n:10,l:2
# accuracy: 88.81
# d:20,n:20,l:0.001
# accuracy: 87.35
# d:20,n:20,l:0.01
# accuracy: 88.45
# d:20,n:20,l:0.05
# accuracy: 90.3
# d:20,n:20,l:0.1
# accuracy: 91.68
# d:20,n:20,l:0.5
# accuracy: 94.19
# d:20,n:20,l:1
# accuracy: 93.74
# d:20,n:20,l:2
# accuracy: 87.68
# d:20,n:50,l:0.001
# accuracy: 87.81
# d:20,n:50,l:0.01
# accuracy: 89.43
# d:20,n:50,l:0.05
# accuracy: 92.2
# d:20,n:50,l:0.1
# accuracy: 93.71
# d:20,n:50,l:0.5

# %% [markdown]
# Best Accuracy Compared to other methods hence further tired using XGBoost with tokenizing texts in XGBoost.ipynb

# %%
from xgboost import XGBClassifier
d, n, l = 10, 50, 0.5
pipeline_model(Pipeline([('vect', CountVectorizer()),
                        ('tfidf', TfidfTransformer()),
                        ('model', XGBClassifier(loss = 'deviance',
                                                learning_rate = l,
                                                n_estimators = n,
                                                max_depth = d,
                                                random_state=2020))]),
                        x_train, y_train, x_test, y_test)
# Out:
# accuracy: 95.27

# %% [markdown]
# Tried using LightGBM, Light Gradient Boosting Machine

# %%
import lightgbm as lgbm


vec = CountVectorizer()
Xtrain = vec.fit_transform(x_train)
Xtest = vec.fit_transform(x_test)
tfidf = TfidfTransformer()
Xtrain = tfidf.fit_transform(Xtrain)
Xtest = tfidf.fit_transform(Xtest)


train_d = lgbm.Dataset(Xtrain, y_train)
eval_d = lgbm.Dataset(Xtest, y_test)

parameters = {
    'objective': 'binary',
    'metric':['accuracy','auc'],
    'is_unbalance': 'true',
    'feature_fraction': 0.8,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'num_threads' : 2,
    'seed' : 76
}

m = lgbm.train(parameters,
                train_d,
                num_boost_round=40,
                valid_sets=eval_d,
                early_stopping_rounds=40)#20)
# Out:
# [1]	valid_0's auc: 0.500389
# Training until validation scores don't improve for 40 rounds.
# [2]	valid_0's auc: 0.502419
# [3]	valid_0's auc: 0.502351
# [4]	valid_0's auc: 0.50235
# [5]	valid_0's auc: 0.501801
# [6]	valid_0's auc: 0.501733
# [7]	valid_0's auc: 0.501734
# [8]	valid_0's auc: 0.50187
# [9]	valid_0's auc: 0.501183
# [10]	valid_0's auc: 0.501049
# [11]	valid_0's auc: 0.501049
# [12]	valid_0's auc: 0.500844
# [13]	valid_0's auc: 0.500844
# [14]	valid_0's auc: 0.500844
# [15]	valid_0's auc: 0.500777
# [16]	valid_0's auc: 0.500778
# [17]	valid_0's auc: 0.50084
# [18]	valid_0's auc: 0.500905
# [19]	valid_0's auc: 0.500905
# [20]	valid_0's auc: 0.500705
# [21]	valid_0's auc: 0.500637
# [22]	valid_0's auc: 0.500633
# [23]	valid_0's auc: 0.50063
# [24]	valid_0's auc: 0.500619
# [25]	valid_0's auc: 0.503528
# [26]	valid_0's auc: 0.503635
# [27]	valid_0's auc: 0.504359
# [28]	valid_0's auc: 0.504352
# [29]	valid_0's auc: 0.504344
# [30]	valid_0's auc: 0.508907
# [31]	valid_0's auc: 0.513253
# [32]	valid_0's auc: 0.51278
# [33]	valid_0's auc: 0.512895
# [34]	valid_0's auc: 0.512902
# [35]	valid_0's auc: 0.512572
# [36]	valid_0's auc: 0.512984
# [37]	valid_0's auc: 0.513047
# [38]	valid_0's auc: 0.51308
# [39]	valid_0's auc: 0.512949
# [40]	valid_0's auc: 0.513047
# Did not meet early stopping. Best iteration is:
# [31]	valid_0's auc: 0.513253
