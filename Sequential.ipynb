# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import feature_extraction, model_selection, preprocessing
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
import glob 
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize
import spacy
from collections import Counter
import re
import random
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
from string import punctuation
import h5py
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
lemmatizer = WordNetLemmatizer()
stop = set(stopwords.words('english'))
stop.update(list(punctuation))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
MAX_NB_WORDS = 50000
MAX_SEQUENCE_LENGTH = 250
EMBEDDING_DIM = 100

# %%
def get_datasets(shuffle=False,processed=False):
    df = pd.DataFrame()
    path = 'Datasets/*/*_*.csv'
    if processed:
        path = 'processed_dataset/*.csv'
    for file in tqdm(glob.glob(path)):
        df = df.append(pd.read_csv(file), ignore_index=True)
    if shuffle:
    	df = df.reindex(np.random.permutation(df.index)).reset_index(drop=True)
    return df

# %%
def normalize(df,difference=300):
    df_list = [df[df['fake']==0],df[df['fake']==1]] # [fact,fake]
    lst = [len(df_list[0]),len(df_list[1])]
    if not bool(lst.index(min(lst))):
        """ if fake is larger then swap """
        df_list[0], df_list[1] = df_list[1], df_list[0]
    size = len(df_list[0]) - len(df_list[1]) + difference
    to_delete = random.sample(range(0, len(df_list[0])), size)
    df_list[0] = df_list[0].drop(df_list[0].index[to_delete])
    return df_list[0].append(df_list[1], ignore_index=True).sample(frac=1)

# %%
def text_clean(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'http\S+', '', text)
    text = " ".join(x for x in word_tokenize(str(text)) if x.strip().lower() not in stop)
    text = re.sub(r'\d+', '', text)
    text = " ".join(lemmatizer.lemmatize(x.lower()) for x in text.split())
    return(text)

# %%
def pre_process(norm=True):
    if norm:
        df = normalize(get_datasets())
        print("Normalized")
    else:
        df = get_datasets(shuffle=True)
    df = df.replace(np.nan, '', regex=True)
    df['news'] = df['title'].str.cat(df['text'],sep=" ")
    print("Cleaning")
    df['news'] = df['news'].progress_apply(text_clean)
    df = df.drop(['title','text'], axis=1)
    return df

# %%
def format_data(df, train=True, tokenizer=None):
    x = df["news"].values
    if train:
        y = df['fake'].values
    if not tokenizer:
        tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
        tokenizer.fit_on_texts(x)
        print('Found %s unique tokens.' % len(tokenizer.word_index))
    x = tokenizer.texts_to_sequences(x)
    x = pad_sequences(x, maxlen=MAX_SEQUENCE_LENGTH)
    if not train:
        return x, tokenizer
    return x, y, tokenizer

# %% [markdown]
# We had already preprocessed dataset in XGBoost.ipynb

# %%
df = get_datasets(shuffle=True,processed=True)
df['news'] = df['news'].apply(str)
df.head()
# Out:
#    fake                                               news
# 0     0  israel approves building plan settler home wes...
# 1     0  america wrong conversation income inequality w...
# 2     0  sen. rand paul lawmaker must take back power b...
# 3     0  ted cruz count army volunteer latest poll show...
# 4     0  louisville took wake forest ’ play ’ fault may...

# %%
X, y, tokenizer = format_data(df)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)
# Out:
# Found 411098 unique tokens.

# %%
print("train: 1:{}, 0:{} | test: 1:{}, 0:{}".format(y_train.tolist().count(1),y_train.tolist().count(0),y_test.tolist().count(1),y_test.tolist().count(0)))
# Out:
# train: 1:29276, 0:138217 | test: 1:7204, 0:34670

# %% [markdown]
# <h3>Keras Sequential with Early Stopping</h3>

# %% [markdown]
# Model

# %%
def sequential(inp):
    model = Sequential()
    model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=inp))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# %% [markdown]
# Training in batches as full dataset does not fit memory

# %%
from keras.callbacks import EarlyStopping

callback = EarlyStopping(monitor='accuracy', mode='max', verbose=1)
              
epochs = 10
batch_size = 500
try:
    model_1 = sequential(x_train.shape[1])
    history_1 = []
    batches = 10
    i = 0
    for batch_x, batch_y in tqdm(zip(np.array_split(x_train, batches),np.array_split(y_train, batches))):
        print('*'*5,i,'*'*5)
        h = model_1.fit(batch_x, batch_y, epochs=epochs, batch_size=batch_size,validation_data=(x_test, y_test), callbacks=[callback])
        history_1.append(h)
        i+=1
except Exception as e:
    print(e)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 250, 100)          5000000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 250, 100)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 5,085,501
# Trainable params: 5,085,501
# Non-trainable params: 0
# _________________________________________________________________
# None
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ***** 0 *****
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 16750 samples, validate on 41874 samples
# Epoch 1/10
# 16750/16750 [==============================] - 40s 2ms/step - loss: 0.4827 - accuracy: 0.8147 - val_loss: 0.3305 - val_accuracy: 0.8496
# Epoch 2/10
# 16750/16750 [==============================] - 40s 2ms/step - loss: 0.2110 - accuracy: 0.9182 - val_loss: 0.1799 - val_accuracy: 0.9389
# Epoch 3/10
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.0968 - accuracy: 0.9676 - val_loss: 0.1716 - val_accuracy: 0.9418
# Epoch 4/10
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.0493 - accuracy: 0.9854 - val_loss: 0.1878 - val_accuracy: 0.9426
# Epoch 5/10
# 16750/16750 [==============================] - 38s 2ms/step - loss: 0.0271 - accuracy: 0.9925 - val_loss: 0.2124 - val_accuracy: 0.9331
# Epoch 6/10
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 0.2578 - val_accuracy: 0.9390
# Epoch 7/10
# 16750/16750 [==============================] - 40s 2ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.2747 - val_accuracy: 0.9368
# Epoch 8/10
# 16750/16750 [==============================] - 40s 2ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.3111 - val_accuracy: 0.9381
# Epoch 9/10
# 16750/16750 [==============================] - 40s 2ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.3117 - val_accuracy: 0.9318
# Epoch 10/10
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0
step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1340 - val_accuracy: 0.9702
# ***** 8 *****
# Train on 16749 samples, validate on 41874 samples
# Epoch 1/10
# 16749/16749 [==============================] - 37s 2ms/step - loss: 0.1233 - accuracy: 0.9607 - val_loss: 0.0943 - val_accuracy: 0.9659
# Epoch 2/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0835 - accuracy: 0.9743 - val_loss: 0.0873 - val_accuracy: 0.9725
# Epoch 3/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0527 - accuracy: 0.9827 - val_loss: 0.0999 - val_accuracy: 0.9707
# Epoch 4/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0379 - accuracy: 0.9876 - val_loss: 0.1046 - val_accuracy: 0.9718
# Epoch 5/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.1166 - val_accuracy: 0.9691
# Epoch 6/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.1154 - val_accuracy: 0.9722
# Epoch 7/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.1190 - val_accuracy: 0.9706
# Epoch 8/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.1291 - val_accuracy: 0.9684
# Epoch 9/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.1393 - val_accuracy: 0.9689
# Epoch 10/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.1480 - val_accuracy: 0.9702
# ***** 9 *****
# Train on 16749 samples, validate on 41874 samples
# Epoch 1/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.1318 - accuracy: 0.9607 - val_loss: 0.1169 - val_accuracy: 0.9601
# Epoch 2/10
# 16749/16749 [==============================] - 40s 2ms/step - loss: 0.0935 - accuracy: 0.9675 - val_loss: 0.0935 - val_accuracy: 0.9687
# Epoch 3/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0543 - accuracy: 0.9822 - val_loss: 0.0871 - val_accuracy: 0.9706
# Epoch 4/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.0991 - val_accuracy: 0.9717
# Epoch 5/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0208 - accuracy: 0.9941 - val_loss: 0.1038 - val_accuracy: 0.9695
# Epoch 6/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.1084 - val_accuracy: 0.9705
# Epoch 7/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0091 - accuracy: 0.9980 - val_loss: 0.1165 - val_accuracy: 0.9714
# Epoch 8/10
# 16749/16749 [==============================] - 37s 2ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.1207 - val_accuracy: 0.9716
# Epoch 9/10
# 16749/16749 [==============================] - 39s 2ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.1277 - val_accuracy: 0.9699
# Epoch 10/10
# 16749/16749 [==============================] - 38s 2ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.1362 - val_accuracy: 0.9717

# %% [markdown]
# Accuracy of the model

# %%
accuracy_score(y_test,model_1.predict_classes(x_test))
# Out:
# 0.9716530544012991
