# %%
import pandas as pd
from collections import Counter
import numpy as np
from tqdm.auto import tqdm

# %%
df = pd.read_csv('fake.csv')

# %%
df.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# ...

# %%
all(df['title'] == df['thread_title'])
# Out:
# False

# %%
# Find % of NA
(df.isna().sum()/len(df))*100
# Out:
# uuid                   0.000000
# ord_in_thread          0.000000
# author                18.647588
# published              0.000000
# title                  5.231172
# text                   0.353873
# language               0.000000
# crawled                0.000000
# site_url               0.000000
# country                1.353950
# domain_rank           32.487114
# thread_title           0.092315
# spam_score             0.000000
# main_img_url          28.025233
# replies_count          0.000000
# participants_count     0.000000
# likes                  0.000000
# comments               0.000000
# shares                 0.000000
# type                   0.000000
# dtype: float64

# %%
len(set(df['uuid']))
# Out:
# 12999

# %%
Counter(df['site_url']).most_common()
# Out:
# [('abeldanger.net', 100),
#  ('abovetopsecret.com', 100),
#  ('activistpost.com', 100),
#  ('ahtribune.com', 100),
#  ('amren.com', 100),
#  ('amtvmedia.com', 100),
#  ('anonhq.com', 100),
#  ('antiwar.com', 100),
#  ('awdnews.com', 100),
#  ('barenakedislam.com', 100),
#  ('beforeitsnews.com', 100),
#  ('blacklistednews.com', 100),
#  ('breitbart.com', 100),
#  ('clickhole.com', 100),
#  ('collective-evolution.com', 100),
#  ('conservativetribune.com', 100),
#  ('counterpunch.org', 100),
#  ('dailystormer.com', 100),
#  ('davidstockmanscontracorner.com', 100),
#  ('dcclothesline.com', 100),
#  ('disclose.tv', 100),
#  ('elmundotoday.com', 100),
#  ('eutimes.net', 100),
#  ('fellowshipoftheminds.com', 100),
#  ('freedomoutpost.com', 100),
#  ('fromthetrenchesworldreport.com', 100),
#  ('frontpagemag.com', 100),
#  ('galacticconnection.com', 100),
#  ('godlikeproductions.com', 100),
#  ('govtslaves.info', 100),
#  ('greanvillepost.com', 100),
#  ('guardianlv.com', 100),
# ...

# %%
df = pd.read_csv('fake.csv',usecols=['text','title'])
df['fake'] = 1
df.head()
# Out:
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text  fake
# 0  Print They should pay all the back all the mon...     1
# 1  Why Did Attorney General Loretta Lynch Plead T...     1
# 2  Red State : \nFox News Sunday reported this mo...     1
# 3  Email Kayla Mueller was a prisoner and torture...     1
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...     1

# %% [markdown]
# Breaking the original Dataset into chunks as the single files are to large to upload

# %%
chunk_df = np.array_split(df, 10)
for chunk in tqdm(range(len(chunk_df))):
    chunk_df[chunk].to_csv('2_{}.csv'.format(chunk),index=False)
